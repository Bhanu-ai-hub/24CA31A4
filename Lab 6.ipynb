# %% [markdown]
# # In-Lab

# %% [markdown]
# ## Simple Python Program

# %%
First install Word2Vec library if needed:

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\bhanu\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\bhanu\anaconda3\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\bhanu\anaconda3\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\bhanu\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##  Code

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# Corpus
sentences = [
    ["i", "love", "machine", "learning"],
    ["i", "enjoy", "artificial", "intelligence"],
    ["cats", "drink", "milk"],
    ["dogs", "drink", "milk"]
]

# Train Word2Vec
model = Word2Vec(
    sentences,
    vector_size=50,
    window=2,
    min_count=1,
    sg=1
)

# Sentence embedding function
def sentence_vector(sentence):
    words = sentence.lower().split()
    vectors = [model.wv[word] for word in words]
    return sum(vectors) / len(vectors)

# Two sentences
s1 = "i love machine learning"
s2 = "i enjoy artificial intelligence"

# Convert sentences to vectors
v1 = sentence_vector(s1)
v2 = sentence_vector(s2)

# Calculate similarity
similarity = cosine_similarity([v1], [v2])[0][0]

print("Sentence 1:", s1)
print("Sentence 2:", s2)
print("Cosine Similarity:", similarity)
# Out:
#   Cell In[1], line 2
#     Simple Python Program
#            ^
# SyntaxError: invalid syntax
